# %%
import pandas as pd

# %%
pd.set_option('display.max_colwidth',None)
pd.set_option('display.max_rows', None)

# %%
data = pd.read_excel("Data Science Interview Question.xlsx")
data.head()
# Out:
#                                                      Company  \
# 0     Data Scientist at L&T Technology Services was asked...
# 1                Data Scientist at ThoughtWorks was asked...
# 2       Junior Data Scientist at Knowledge Lens was asked...
# 3                 Data Scientist at Wells Fargo was asked...
# 4  Data Science Associate at Redwood Associates was asked...
#
#                                                                                                                                                              Question  \
# 0  What are data types in python, how to instantiate tensor, what are tensors, tell me about your role, what are the different phases of a data science project, etc.
# 1                                                                                                                                                  Banking case study
# ...

# %%
data['Company']
# Out:
# 0                                                       Data Scientist at L&T Technology Services was asked...
# 1                                                                  Data Scientist at ThoughtWorks was asked...
# 2                                                         Junior Data Scientist at Knowledge Lens was asked...
# 3                                                                   Data Scientist at Wells Fargo was asked...
# 4                                                    Data Science Associate at Redwood Associates was asked...
# 5                                                               Data Scientist at Tiger Analytics was asked...
# 6                                                                     Data Scientist at Tokopedia was asked...
# 7                                                             Associate Data Scientist at AppsTek was asked...
# ...

# %%
data['Company'] = data['Company'].str.replace('Data Scientist', '')
data['Company'] = data['Company'].str.replace('was asked...', '')
data['Company'] = data['Company'].str.replace('Associate', '')
data['Company'] = data['Company'].str.replace('at', '')
data['Company'] = data['Company'].str.replace('Junior', '')
data['Company'] = data['Company'].str.replace('Data Science', '')
data['Company'] = data['Company'].str.replace('Entry', '')
data['Company'] = data['Company'].str.replace('Level', '')
data['Company'] = data['Company'].str.replace('Senior', '')
data['Company'] = data['Company'].str.replace('Da Science', '')
data['Company'] = data['Company'].str.replace('Business', '')
data['Company'] = data['Company'].str.replace('Analyst', '')
data['Company'] = data['Company'].str.replace('Engineer ', '')
data['Company'] = data['Company'].str.replace('Lead', '')
data['Company'] = data['Company'].str.replace('/', '')
data['Company'] = data['Company'].str.replace('Specialist', '')
data['Company'] = data['Company'].str.replace('Python', '')
data['Company'] = data['Company'].str.replace('ML', '')
data['Company'] = data['Company'].str.replace('Technical Staff', '')
data['Company'] = data['Company'].str.replace('Member', '')
data['Company'] = data['Company'].str.replace('Vice President', '')
data['Company'] = data['Company'].str.replace('Progammar  ', '')
data['Company'] = data['Company'].str.replace('Nural Language ProcessingMachine LearningText Mining', '')
data['Company'] = data['Company'].str.replace('Machine Learning', '')  
data['Company'] = data['Company'].str.replace('and Analytics', '')
data['Company'] = data['Company'].str.replace('Trainee', '')  
data['Company'] = data['Company'].str.replace('of -', '')  
data['Company'] = data['Company'].str.replace('For ', '') 
data['Company'] = data['Company'].str.replace('Staff', '')
data['Company'] = data['Company'].str.replace('Quality Assessment ', '')
data['Company'] = data['Company'].str.replace('Fellow', '')
data['Company'] = data['Company'].str.replace('Product Innovion', '')
data['Company'] = data['Company'].str.replace('- IT', '')
data['Company'] = data['Company'].str.replace('Consultant', '') 
data['Company'] = data['Company'].str.replace('Executive', '')    
data['Company'] = data['Company'].str.replace('Clinical', '')    
data['Company'] = data['Company'].str.replace('-', '')      
data['Company'] = data['Company'].str.replace('Manager', '')

# %%
data['Company'] = data['Company'].str.strip()

# %%
data['Company']
# Out:
# 0                                           L&T Technology Services
# 1                                                      ThoughtWorks
# 2                                                    Knowledge Lens
# 3                                                       Wells Fargo
# 4                                                         Redwood s
# 5                                                   Tiger Analytics
# 6                                                         Tokopedia
# 7                                                           AppsTek
# 8                                                      Robert Bosch
# 9                                                      Robert Bosch
# 10                                                          Bidgely
# 11                                         Motilal Oswal Securities
# 12                                                            Paytm
# 13                                                             NIRA
# ...

# %%
data.to_excel("glassdoor_DS_Interview.xlsx")

# %%
df = pd.read_csv("Data Analyst Interview Questions.csv")
df.head()
# Out:
#                                                  Company  \
# 0  Data Analyst at Acuverco Pharmaceuticals was asked...
# 1                      Data Analyst at Zoho was asked...
# 2   Data Analyst at Arzenovo Pharmaceutical was asked...
# 3                     Data Analyst at Modak was asked...
# 4               Data Analyst at GlobalLogic was asked...
#
#                                                                                                               Question  \
# 0                                                                                                    Describe yourself
# 1  100 even number in ascending order first 50 number average is N then all the number average is a N+49 B N+50 C N+55
# 2                                                                                                    Linear regression
# 3                                                                                      almost evrything on java ,DBMS.
# ...

# %%
df['Company']
# Out:
# 0                                                   Data Analyst at Acuverco Pharmaceuticals was asked...
# 1                                                                       Data Analyst at Zoho was asked...
# 2                                                    Data Analyst at Arzenovo Pharmaceutical was asked...
# 3                                                                      Data Analyst at Modak was asked...
# 4                                                                Data Analyst at GlobalLogic was asked...
# 5                                               Research and Data Analyst at Opera Solutions was asked...
# 6                                                                  Data Analyst at BRIDGEi2i was asked...
# 7                                                                  Data Analyst at BRIDGEi2i was asked...
# 8                                                                       Data Analyst at Zoho was asked...
# ...

# %%
df['Company'] = df['Company'].str.replace('Data Scientist', '')
df['Company'] = df['Company'].str.replace('was asked...', '')
df['Company'] = df['Company'].str.replace('Associate', '')
df['Company'] = df['Company'].str.replace('at', '')
df['Company'] = df['Company'].str.replace('Junior', '')
df['Company'] = df['Company'].str.replace('Data Science', '')
df['Company'] = df['Company'].str.replace('Entry', '')
df['Company'] = df['Company'].str.replace('Level', '')
df['Company'] = df['Company'].str.replace('Senior', '')
df['Company'] = df['Company'].str.replace('Da Science', '')
df['Company'] = df['Company'].str.replace('Business', '')
df['Company'] = df['Company'].str.replace('Analyst', '')
df['Company'] = df['Company'].str.replace('Engineer ', '')
df['Company'] = df['Company'].str.replace('Lead', '')
df['Company'] = df['Company'].str.replace('/', '')
df['Company'] = df['Company'].str.replace('Specialist', '')
df['Company'] = df['Company'].str.replace('Python', '')
df['Company'] = df['Company'].str.replace('ML', '')
df['Company'] = df['Company'].str.replace('Technical Staff', '')
df['Company'] = df['Company'].str.replace('Member', '')
df['Company'] = df['Company'].str.replace('Vice President', '')
df['Company'] = df['Company'].str.replace('Progammar  ', '')
df['Company'] = df['Company'].str.replace('Nural Language ProcessingMachine LearningText Mining', '')
df['Company'] = df['Company'].str.replace('Machine Learning', '')  
df['Company'] = df['Company'].str.replace('and Analytics', '')
df['Company'] = df['Company'].str.replace('Trainee', '')  
df['Company'] = df['Company'].str.replace('of -', '')  
df['Company'] = df['Company'].str.replace('For ', '') 
df['Company'] = df['Company'].str.replace('Staff', '')
df['Company'] = df['Company'].str.replace('Quality Assessment ', '')
df['Company'] = df['Company'].str.replace('Fellow', '')
df['Company'] = df['Company'].str.replace('Product Innovion', '')
df['Company'] = df['Company'].str.replace('- IT', '')
df['Company'] = df['Company'].str.replace('Consultant', '') 
df['Company'] = df['Company'].str.replace('Executive', '')    
df['Company'] = df['Company'].str.replace('Clinical', '')    
df['Company'] = df['Company'].str.replace('-', '')      
df['Company'] = df['Company'].str.replace('Manager', '')
df['Company'] = df['Company'].str.replace('Da', '')
df['Company'] = df['Company'].str.replace('Research', '')
df['Company'] = df['Company'].str.replace('Big', '')

# %%
df['Company'] = df['Company'].str.strip()

# %%
df['Company']
# Out:
# 0                                  Acuverco Pharmaceuticals
# 1                                                      Zoho
# 2                                   Arzenovo Pharmaceutical
# 3                                                     Modak
# 4                                               GlobalLogic
# 5                                    and    Opera Solutions
# 6                                                 BRIDGEi2i
# 7                                                 BRIDGEi2i
# 8                                                      Zoho
# 9                           Freshers  Nash Ventures (India)
# 10                                                 Tredence
# 11                                                    Zycus
# 12                                                 Alphonso
# 13                              Cogencis Informion Services
# 14                                     Course5 Intelligence
# 15                                                     Zoho
# ...

# %%
df.to_excel("glassdoor_DA_Interview.xlsx")
